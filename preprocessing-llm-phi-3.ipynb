# %%
import json
import os

# %%
path = '/kaggle/input/d/anannayjain/schema'
data_models = {}
for name in os.listdir(path) :
    with open(os.path.join(path,name)) as f:
        table_name = name.split('.')[0]
        data_models[table_name] = json.load(f)

# %%
with open('/kaggle/input/d/anannayjain/schema/relationships_minimized.json') as f:
    relationships=json.load(f)

# %%
table_name = data_models.keys()

# %%
data_models['customer_1']['columns']
# Out:
# [{'name': 'customer_id',
#   'description': 'Unique identifier for the customer',
#   'data_type': 'STRING',
#   'format': '',
#   'is_pii_column': 'Y',
#   'enum': [],
#   'dimension_group': ''},
#  {'name': 'first_name',
#   'description': "Customer's first name",
#   'data_type': 'STRING',
#   'format': 'CamelCase',
#   'is_pii_column': 'Y',
#   'enum': [],
#   'dimension_group': 'customer_dimension_group'},
#  {'name': 'last_name',
#   'description': "Customer's last name",
#   'data_type': 'STRING',
#   'format': 'CamelCase',
#   'is_pii_column': 'Y',
#   'enum': [],
#   'dimension_group': 'customer_dimension_group'},
#  {'name': 'email',
#   'description': "Customer's email address",
#   'data_type': 'STRING',
#   'format': 'LowerCase',
#   'is_pii_column': 'Y',
#   'enum': [],
#   'dimension_group': 'customer_dimension_group'},
#  {'name': 'phone_number',
#   'description': "Customer's contact number",
#   'data_type': 'STRING',
#   'format': '',
#   'is_pii_column': 'Y',
# ...

# %%
def identify_tables_and_relationships(question, data_models, relationships):
    relevant_tables = []
    relevant_relationships = []
    
#     keywords_to_tables = {
#         "order placement": ["order"],
#         "shipment": ["shipping_details"],
#         "product categories": ["product_categories"],
#         "customer regions": ["customer_address_history_0","customer_address_history_1"],
#         "order volume": ["order"],
#         "shopping hours": ["browsing_history"],
#         "customer purchases": ["order", "customer_0"],
#         "e-commerce platform": ["browsing_history_0"],
#         "initial and subsequent purchases": ["order", "customer_0"],
#         "website downtime": ["website_performance_fact"],
#         "sales revenue": ["order", "sales_fact"],
#         "customer satisfaction": ["reviws_0", "reviws_1"],
#         "server logs": ["website_performance_fact"],
#         "geographic": ["customer_0"],
#         "product preferences": ["wishlist_0", "wishlist_1"],
#         "promotional periods": ["marketing_fact"]
#     }
    keywords_to_tables = {
        
        "order placement": ["order"],
        "shipment": ["shipping_details"],
        "product categories": ["product_categories"],
        "customer regions": ["customer_address_history_0","customer_address_history_1"],
        "order volume": ["order"],
        "customer purchases": ["order", "customer_0"],
        "e-commerce platform": ["browsing_history_0"],
        "initial and subsequent purchases": ["order", "customer_0"],
        "website downtime": ["website_performance_fact"],
        "sales revenue": ["order", "sales_fact"],
        "customer satisfaction": ["reviws_0", "reviws_1"],
        "server logs": ["website_performance_fact"],
        "product preferences": ["wishlist_0", "wishlist_1"],
        "promotional periods": ["marketing_fact"],
        'shopping hours': ['sales_transaction', 'order', 'order_details', 'browsing_history_0', 'browsing_history_1'],
        'duration between purchases': ['sales_transaction', 'order', 'customer_interaction_fact'],
        'website downtime': ['website_performance_fact', 'sales_fact'],
        'geographic': ['customer_address_history_0', 'customer_address_history_1', 'sales_fact', 'order', 'product_sales'],
        'engagement trends': ['browsing_history_0', 'browsing_history_1', 'customer_activity_0', 'customer_activity_1'],
        'hourly distribution': ['browsing_history_0', 'browsing_history_1', 'sales_transaction', 'order'],
        'weekends and holidays': ['sales_transaction', 'order', 'order_details'],
        'order processing time': ['order', 'shipping_details', 'order_fulfillment_fact', 'product_category', 'customer_address_history_0', 'customer_address_history_1'],
        'spending and satisfaction': ['sales_transaction', 'order', 'customer_interaction_fact'],
        'price increase': ['product_category_pricing', 'product_sales', 'sales_fact'],
        'purchase patterns': ['sales_transaction', 'order', 'product_category', 'product_sales', 'customer_address_history_0', 'customer_address_history_1'],
        'quantity exceeds average': ['order_details', 'product_sales', 'sales_transaction'],
        'missing shipping dates': ['order', 'shipping_details'],
        'missing data': ['customer_activity_0', 'customer_activity_1', 'browsing_history_0', 'browsing_history_1'],
        'COALESCE': ['product_category', 'product'],
        'essential data': ['sales_transaction', 'order'],
        'cumulative revenue': ['sales_fact', 'product_category', 'customer_address_history_0', 'customer_address_history_1'],
        'average order value': ['sales_transaction', 'order', 'customer_address_history_0', 'customer_address_history_1'],
        'window function': ['sales_transaction', 'order'],
        'moving average': ['sales_fact', 'product_category', 'customer_address_history_0', 'customer_address_history_1'],
        'top-performing products': ['sales_fact', 'product_sales', 'product_category'],
        'monthly percentage change': ['sales_fact', 'product_category'],
        'loyalty points': ['loyalty_program_0', 'loyalty_program_1'],
        'purchase quantities': ['order_details', 'product_sales', 'sales_transaction'],
        'return rates': ['sales_transaction', 'order', 'order_details'],
        'monthly discounts': ['sales_fact', 'product_sales', 'product_category'],
        'product ratings': ['reviews_0', 'reviews_1'],
        'annual revenue': ['sales_fact', 'product_category', 'customer_address_history_0', 'customer_address_history_1'],
        'daily breakdown': ['sales_fact', 'product_sales', 'product_category'],
        'payment methods': ['sales_transaction', 'order'],
        'customer profiles': ['customer_0', 'customer_1', 'sales_transaction', 'order'],
        'product descriptions': ['product', 'product_category'],
        'customer orders': ['order', 'shipping_details'],
        'geographic impact': ['customer_address_history_0', 'customer_address_history_1', 'sales_fact'],
        'monthly revenue': ['sales_fact', 'product_category'],
        'sales volume': ['sales_fact', 'product_sales', 'product_category'],
        'order value': ['sales_transaction', 'order', 'customer_address_history_0', 'customer_address_history_1'],
        'shipping costs': ['order', 'shipping_details'],
        'sales channel': ['sales_fact', 'product_category'],
        'product returns': ['order', 'shipping_details', 'order_fulfillment_fact'],
        'customer type': ['customer_0', 'customer_1', 'sales_fact'],
        'transaction analysis': ['sales_transaction', 'order'],
        'quarterly trends': ['sales_fact', 'product_category'],
        'customer segmentation': ['customer_0', 'customer_1', 'sales_transaction', 'order'],
        'sales bonuses': ['sales_fact', 'sales_transaction', 'order'],
        'day of the week': ['sales_transaction', 'order'],
        'satisfaction scores': ['customer_interaction_fact', 'reviews_0', 'reviews_1'],
        'purchase value': ['sales_transaction', 'order', 'customer_address_history_0', 'customer_address_history_1'],
        'revenue trends': ['sales_fact', 'product_category'],
        'geographic areas': ['customer_address_history_0', 'customer_address_history_1', 'sales_fact'],
        'revenue': ['sales_fact', 'product_category'],
        'revenue analysis': ['sales_fact', 'product_category'],
        'shipping delays': ['order', 'shipping_details'],
        'return rate': ['order', 'shipping_details', 'order_fulfillment_fact'],
        'product attributes': ['product', 'product_category'],
        'missing values': ['customer_activity_0', 'customer_activity_1', 'browsing_history_0', 'browsing_history_1'],
        'email addresses': ['customer_0', 'customer_1'],
        'domain analysis': ['customer_0', 'customer_1'],
        'customer names': ['customer_0', 'customer_1'],
        'transaction analysis': ['sales_transaction', 'order'],
        'peak sales': ['sales_fact', 'product_category'],
        'revenue increase': ['sales_fact', 'product_category'],
        'seasonal trends': ['sales_fact', 'product_category'],
        'lifetime value': ['sales_fact', 'customer_interaction_fact'],
        'repeat purchases': ['sales_transaction', 'order'],
        'purchase patterns': ['sales_transaction', 'order'],
        }

    
    # Define table names from JSON schemas
    table_names = data_models.keys()
    
    # Identify relevant tables
    for keyword, tables in keywords_to_tables.items():
        if keyword in question.lower():
            for table in tables:
                if table in table_names and table not in relevant_tables:
                    relevant_tables.append(table)
                    
    
    # Identify relevant relationships
    for table in relevant_tables:
        if table in relationships:
            for relation in relationships[table]:
                relevant_relationships.append(relation)

    return relevant_tables, relevant_relationships

# %%
# Example questions
questions = [
    "What is the average duration from order placement to shipment across different product categories, segmented by customer regions and order volume?",
    "How can I determine the peak shopping hours by analyzing the times at which customers complete their purchases on our e-commerce platform?",
    "Can you help analyze the average duration between initial and subsequent purchases by customers, focusing on their purchase patterns and engagement levels?",
    "How can I determine the impact of website downtime on sales revenue and customer satisfaction by analyzing the timestamps from server logs?",
    "How can we analyze customer purchases, focusing on geographic and product preferences, during promotional periods to enhance sales strategies and improve customer satisfaction?"
]

# %%
# Analyze each question
generated_answers=[]
for question in questions:
    tables,relationship = identify_tables_and_relationships(question, data_models, relationships)
    tc=[]
    for table in tables:
        tc.append(data_models[table])
    answer = f"Table_information:{tc} \n Relevant Relationships: {relationship}"
    generated_answers.append(answer)
# Save generated answers
with open('generated_answers.json', 'w') as f:
    json.dump(generated_answers, f, indent=4)

# %%
data_models.keys()
# Out:
# dict_keys(['customer_0', 'wishlist_0', 'customer_interaction_fact', 'product_sales', 'customer_address_history_0', 'customer_support_0', 'product_recommendation', 'sales_fact', 'browsing_history_0', 'product', 'loyalty_program_0', 'inventory_fact', 'reviews_1', 'supply_chain_fact', 'browsing_history_1', 'loyalty_program_1', 'website_performance_fact', 'adjustment_details', 'customer_activity_0', 'customer_address_history_1', 'reviews_0', 'product_category_hierarchy', 'product_category', 'relationships_minimized', 'customer_search_0', 'product_category_pricing', 'customer_service_fact', 'operational_metrics_fact', 'wishlist_1', 'customer_activity_1', 'sales_transaction', 'shipping_details', 'marketing_fact', 'order', 'customer_search_1', 'order_details', 'order_fulfillment_fact', 'product_category_attributes', 'customer_support_1', 'customer_1'])

# %%
# Example questions
questions = ['How can I determine the peak shopping hours by analyzing the times at which customers complete their purchases on our e-commerce platform?',
 'Can you help analyze the average duration between initial and subsequent purchases by customers, focusing on their purchase patterns and engagement levels?',
 'How can I determine the impact of website downtime on sales revenue and customer satisfaction by analyzing the timestamps from server logs?',
 'How can we analyze customer purchases, focusing on geographic and product preferences, during promotional periods to enhance sales strategies and improve customer satisfaction?',
 'Can you analyze the duration between the initial and most recent session for each customer to assess engagement trends over time?',
 'How can I evaluate the hourly distribution of customer visits to our e-commerce platform to enhance targeted marketing strategies and improve user engagement?',
 'How can I analyze customer purchase patterns during weekends and holidays to enhance targeted marketing strategies?',
 'Can you show how to calculate the average time taken to process orders for each delivery method, segmented by product category and customer region, while also considering the impact on customer satisfaction and order value?',
 'How can I identify customers from specific regions who have spent more than $500 in the last month and assess their satisfaction scores?',
 'How can I identify products in specific categories that have experienced a price increase greater than 10% over the past year, and analyze their impact on sales volume and customer satisfaction?',
 'Can you help identify customers who have bought products from both the clothing and electronics categories, focusing on their purchase patterns and frequency over the last year across different regions?',
 'How can I identify transactions where the quantity of a specific product exceeds the average quantity purchased across all products within a given time period?',
 'How can I substitute missing shipping dates with corresponding order dates to enhance the accuracy of order processing analysis in an e-commerce setting?',
 'How can I address missing data in the last login details of customers to accurately measure their engagement levels and interaction frequency on our e-commerce platform?',
 "How can we apply COALESCE to manage missing product descriptions in our online catalog, substituting them with 'No description available', to enhance the shopping experience and potentially increase conversion rates?",
 'What is the most effective method to identify e-commerce transactions that lack essential data such as total sales amount or revenue?',
 'How can I determine the cumulative revenue generated by each product category over the past year, segmented by customer region and device type?',
 'How can we categorize customers by their average order value and total purchases across different geographic locations?',
 'How does the average order value per customer in their respective geographic regions compare to the regional average, utilizing a window function analysis?',
 'How can I apply a window function to calculate the 30-day moving average of daily revenue, considering product categories and customer regions?',
 'How can we determine the top-performing products in terms of revenue within each product category, focusing on customer purchase patterns and product availability?',
 "Can you demonstrate how to compute the monthly percentage change in revenue for each category of products, comparing it with the prior month's performance?",
 'How can I calculate the month-over-month growth in the number of customers earning loyalty points, segmented by their membership status and geographic location?',
 'How can I analyze the variation in purchase quantities between successive transactions by individual customers over a specific period?',
 'How can we analyze the impact of product categories and return reasons on return rates to optimize our e-commerce strategy?',
 'Can you provide a monthly breakdown of total discounts offered for each product category, including the average order value and return rate for those products?',
 'How can I generate a report showing the monthly average product ratings by category, segmented by customer feedback over different periods?',
 'How can I analyze the annual revenue and average order value across different product categories and customer regions?',
 'Can you provide a daily breakdown of sales volumes by product category for the last month, highlighting any significant trends in customer purchases and product performance?',
 'How can we analyze and display the variation in payment methods preferred by customers from various regions during different times of the year?',
 'How can I integrate customer profiles with their transaction records to show all customers, including those without any purchase history, while considering their geographical and behavioral attributes, and analyzing metrics like total sales and customer retention rates?',
 'How can I view detailed product descriptions and inventory levels alongside revenue performance, including for items that have not yet been purchased?',
 'Can you help me generate a report that integrates geographic and transaction data to identify which customer orders are still awaiting shipment and analyze the associated revenue impact?',
 'How can I analyze the impact of different geographic regions on e-commerce sales performance, including regions without a physical store presence, by integrating regional customer data with overall business metrics?',
 'How can I find the monthly revenue and average discount per product category, along with the total sales performance?',
 'Can you provide the total sales volume and revenue for each product, by store location and for each product-store combination, over the last quarter?',
 'How can I evaluate the average order value and total number of orders segmented by customer age group and time of day, as well as the combined influence of these factors on sales performance?',
 'How can we analyze the total, average, and maximum shipping costs based on different shipping methods and customer locations in the context of e-commerce transactions?',
 'Can you determine the total revenue and average order value for each product category and sales channel, as well as for each unique combination of category and channel?',
 'How can I determine the total number of product returns, total revenue, and return rate for each product category, segmented by customer region and time period?',
 'How can I find the annual total number of customers, total revenue, and average order value segmented by customer type and time period?',
 'Can you provide a monthly analysis of average order value, total number of transactions, and aggregate discount amounts, segmented by geographic sales regions and also consolidated across all regions?',
 'How can we compare the quarterly revenue trends and average order values across different product categories and regions to identify sales patterns?',
 'How can we segment customers into high, medium, and low spending categories based on their total expenditure and purchase frequency over the past year?',
 'How can we determine bonus payouts for sales representatives based on their achieved sales volumes across various product categories and customer segments over different time periods?',
 'How can I view the total revenue and average order value for each customer segment over the last quarter, segmented by geographic region?',
 'How does the average order value and total number of transactions vary by day of the week for different product categories?',
 'Can you determine the average customer satisfaction score for each product category over the last quarter, segmented by customer region and device type?',
 'What query would identify product categories where the average purchase value exceeded $500 in the past year, segmented by customer region and device type?',
 'What are the months during which revenue fell below $20,000 for each category of products?',
 'Can you identify the geographic areas where customers with a lifetime value over $1,000 predominantly purchase high-rated products, and detail their average order values and retention rates?',
 'Which product categories recorded over 50 transactions with an average discount of at least 10% in the previous quarter, and how did this impact customer satisfaction and revenue?',
 'How can I identify customers who have placed more than 100 orders but have an average order value below $200?',
 'What is the average order value for customer segments with over 30 transactions during the last quarter?',
 'Can you identify which days of the week experienced lower than average sales volumes and customer transactions?',
 'What are the products that have maintained a low customer satisfaction score with more than ten reviews over the past year?',
 'What are the product categories that experienced shipping delays of over a week for more than five transactions within a specific period?',
 'What are the best-performing products in terms of sales volume that also have a return rate exceeding 5%?',
 'How can I identify product categories with an average order value that exceeds the site-wide average, segmented by customer region and purchase period?',
 'Can you provide a monthly analysis of average order value, total revenue, and discount percentages, segmented by geographic region and aggregated for all regions?',
 'How can we assess the effectiveness of our e-commerce strategies by examining the quarterly revenue trends and average order values across different product categories and geographic regions?',
 "How can we segment customers into 'high', 'medium', and 'low' spending categories based on their overall spending, purchase frequency, and average order value over a specific period?",
 'How can we assess the performance bonuses for e-commerce sales representatives by analyzing their sales volumes, regional achievements, and sales trends over specific time periods?',
 'How can we modify shipping fees to offer discounts for larger purchases, while accounting for variations in delivery locations and changes in buying patterns during different seasons?',
 'How can we adjust the pricing strategy for different product categories, like essentials versus luxuries, to reflect varying tax rates and ensure these adjustments are systematically updated each year to optimize revenue and compliance?',
 'How can we differentiate between weekend and weekday sales in terms of average order value and website visits to assess performance variations?',
 "Can you analyze the preferred payment methods for customers by categorizing transactions into 'card', 'cash', or 'other', and provide insights on the usage frequency and average order value for each payment method?",
 'How can I identify customers who have placed more than 100 orders but with an average order value below $200, and also determine the total revenue generated by each of these customers?',
 'What is the average number of products per transaction for customer groups with over 30 transactions, including their average transaction value and the most commonly purchased product?',
 'Can you identify which days of the week had total sales below the average, detailing the percentage difference from the average sales, and also show the total number of transactions for those days?',
 'Which products have maintained a review score below 3 with over 10 reviews in the last year, and what is their average selling price?',
 'How can I pinpoint which product categories had more than five transactions where delivery exceeded seven days, along with the average delivery duration and total transaction count for these categories?',
 'What are the best-performing products with a return rate over 5%, including their categories, price brackets, and consumer ratings?',
 'How can I determine which product categories have an average order value exceeding the site-wide average, including the count of items and total revenue per category?',
 'Can you identify the geographic regions where the total annual revenue last year exceeded the combined average of all regions, and also provide the percentage by which they exceeded this average?',
 'Can you identify the months during which the return rate exceeded the annual average, and also provide the percentage increase in returns compared to the yearly average?',
 'How can I determine which product categories experienced higher than average discount rates, and also assess the total revenue and product count within those categories?',
 'How can I identify which products in specific categories and from certain brands have seen a price increase of over 10% compared to the previous year, and how has this affected their sales volume and customer satisfaction scores?',
 'Can you help determine which customers have bought items from both the apparel and tech sections, including their total expenditure and transaction count for each section?',
 'How can I identify transactions where the quantity of a specific product exceeds the average quantity sold, including information on the purchase date, customer details, and product description?',
 'How can we identify customers who have not engaged in transactions over the past three months, including details on their most recent transaction date and their total expenditure in the last year?',
 'Can you analyze the e-commerce transactions to identify orders placed after a certain date but shipped before another, including details like order ID, customer name, and total value?',
 'How can I pinpoint products that not only exceed the average product rating but also fall within specific price brackets and categories, to enhance customer satisfaction and potentially increase sales revenue?',
 'How can I identify e-commerce transactions where the total order value exceeds the sum of individual product prices, including specifics like transaction ID, customer details, and transaction date?',
 'How can we identify customers whose shipping expenses exceed 20% of their total spending, including detailed figures on their overall expenditure and the proportion allocated to shipping fees?',
 'How can we identify orders placed within 30 minutes of the last site interaction, factoring in the order value, geographic location of the customer, and the time of day?',
 'How does the exponential moving average of monthly revenue over the past year compare to the simple moving average in identifying sales trends and smoothing out fluctuations for different product categories and customer segments?',
 'How does the inclusion of shipping fees, promotional discounts, tax implications, and loyalty program reductions impact the average order value for customers from different regions over the last quarter?',
 'How can I integrate customer purchase data with promotional discount information to show all transactions, highlighting which ones utilized discount codes and the value of the discounts applied?',
 'How can we analyze the impact of seasonal trends and supplier lead times on our inventory turnover and revenue, particularly focusing on products that have not yet been sold?',
 'How can we effectively link customer profiles with their purchase history and subscription status across various regions, ensuring comprehensive inclusion even for inactive accounts, while also maintaining data integrity and privacy?',
 'How can I identify products that have never been purchased, their associated categories, and geographic locations, while also analyzing the inventory levels and product attributes for these items?',
 'How can I refine our e-commerce sales forecasting methods to account for incomplete historical data, while considering seasonal variations and evolving market trends?',
 'How can we compute the average order value incorporating products with missing price data as zero, and also determine the standard deviation along with the total number of transactions for a specific period?',
 'How can we identify the number of customers without registered email addresses and ascertain the proportion of these customers who have completed transactions in the past year?',
 'How can we effectively handle missing values in customer demographic and purchase history data to enhance the accuracy and reliability of our analysis on shopping behavior and sales trends?',
 'Can you provide an analysis that excludes products with incomplete inventory data from total stock calculations, while also detailing supplier information and product classifications?',
 'How can I replace missing delivery dates with the corresponding purchase dates for better analysis of order timelines, and ensure consistency in date formats across e-commerce transaction records?',
 "What methods can be used to address missing data in a customer's last activity date to ensure accurate and consistent measurement of engagement metrics in an e-commerce setting?",
 'What is the total number of customers who have made purchases from India on our platform, including the average order value and the most frequently bought product category?',
 'Can you provide a breakdown of the different email domains used by our customers, including the number and percentage of total customers associated with each domain, segmented by customer region and loyalty program status?',
 "How many customers, whose first names begin with 'J' and who completed a transaction in the previous year, are there?",
 "How many customers, whose names begin with 'Ab' and have email addresses ending in '@gmail.com', made purchases last month in the northeastern region, and what was their average order value?",
 "How many customers with names ending in 'ab' have made purchases in the past year, and what is the total revenue generated from these transactions?",
 "How many customers, whose names contain 'ck', have registered in the past year and what is their average order value?",
 'What is the average duration from registration to first purchase for customers, categorized by the year they signed up and the type of products they bought?',
 'How can we identify the peak sales day of the week in the previous year, focusing on total revenue and transaction count?',
 'How can we calculate the percentage increase in revenue on Black Friday compared to the average of the previous month, segmented by product category and geographic region?',
 'How can I analyze customer buying patterns over different seasons to identify high-demand products and optimize our inventory levels accordingly?',
 'How do you determine the customer lifetime value for an e-commerce shopper from their initial to most recent transaction, factoring in elements such as discount rates and retention expenses?',
 'How can I identify customers who have made repeat purchases in consecutive months and what is their average order value during these transactions?']

# %%
import json

question_answer_pairs = [
    {
        "instruction": "Analyze the question and identify relevant tables and relationships.",
        "input": question,
        "output": f"Relevant Tables: {tables}\nRelevant Relationships: {relationships}"
    }
    for question, (tables, relationships) in zip(questions, map(lambda q: identify_tables_and_relationships(q, data_models, relationships), questions))
]

# Save to a JSON file
with open("final.json", "w") as f:
    json.dump(question_answer_pairs, f, indent=4)

# %%
# # Analyze each question
# generated_answers=[]
# for question in questions:
#     tables,relationship = identify_tables_and_relationships(question, data_models, relationships)
#     tc=[]
#     for table in tables:
#         tc.append(data_models[table])
#     answer = f"Table_information:{tc} \n Relevant Relationships: {relationship}"
#     generated_answers.append(answer)
# # Save generated answers
# with open('generated_answers.json', 'w') as f:
#     json.dump(generated_answers, f, indent=4)

# %%
generated_answer=[] 
for question, (tables, relationships) in zip(questions, map(lambda q: identify_tables_and_relationships(q, data_models, relationships), questions)):
    tc=[]
    for table in tables:
        tc.append(data_models[table])
    answer = {
        "instruction": "Analyze the question and identify relevant tables and relationships.",
        "input": question,
        "output": f"Relevant Tables: {tc}\n Relevant Relationships: {relationships}"
    }
    generated_answer.append(answer)
    
with open('generated_answer.json', 'w') as f:
    json.dump(generated_answer, f, indent=4)

# %%
data_models['order']
# Out:
# [{'name': 'order_id',
#   'description': 'Unique identifier for the order',
#   'data_type': 'STRING',
#   'format': '',
#   'is_pii_column': 'N',
#   'enum': [],
#   'dimension_group': ''},
#  {'name': 'order_item_id',
#   'description': 'Identifier for items within an order',
#   'data_type': 'STRING',
#   'format': '',
#   'is_pii_column': 'N',
#   'enum': [],
#   'dimension_group': ''},
#  {'name': 'customer_id',
#   'description': 'Unique identifier for the customer',
#   'data_type': 'STRING',
#   'format': '',
#   'is_pii_column': 'Y',
#   'enum': [],
#   'dimension_group': 'customer_dimension_group'},
#  {'name': 'product_id',
#   'description': 'Unique identifier for the product',
#   'data_type': 'STRING',
#   'format': '',
#   'is_pii_column': 'N',
#   'enum': [],
#   'dimension_group': 'product_dimension_group'},
#  {'name': 'quantity',
#   'description': 'Number of products ordered',
#   'data_type': 'INTEGER',
#   'format': '',
#   'is_pii_column': 'N',
#   'enum': [],
# ...

# %%
from datasets import load_dataset, Dataset

# Load your custom JSON dataset
dataset = Dataset.from_json("custom_alpaca_data.json")

# %% [markdown]
# Fine_tune!

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.26" trl peft accelerate bitsandbytes
